# %% [markdown]
# **Quantize SeaLLM-7B-Chat with ExLlamaV2**
#
# Inspired from this [original notebook](https://colab.research.google.com/drive/1yrq4XBlxiA0fALtMoT2dwiACVc77PHou?usp=sharing)

# %%
"""Install ExLLamaV2"""
# !git clone https://github.com/turboderp/exllamav2
# !pip install -e exllamav2
# Out:
# Cloning into 'exllamav2'...
# remote: Enumerating objects: 2517, done.
# remote: Counting objects: 100% (1248/1248), done.
# remote: Compressing objects: 100% (457/457), done.
# remote: Total 2517 (delta 899), reused 1034 (delta 789), pack-reused 1269
# Receiving objects: 100% (2517/2517), 2.73 MiB | 8.60 MiB/s, done.
# Resolving deltas: 100% (1687/1687), done.
# Obtaining file:///content/exllamav2
#   Preparing metadata (setup.py) ... done
# Requirement already satisfied: pandas in /usr/local/lib/python3.10/dist-packages (from exllamav2==0.0.11) (1.5.3)
# Collecting ninja (from exllamav2==0.0.11)
#   Downloading ninja-1.11.1.1-py2.py3-none-manylinux1_x86_64.manylinux_2_5_x86_64.whl (307 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 307.2/307.2 kB 6.1 MB/s eta 0:00:00
# Collecting fastparquet (from exllamav2==0.0.11)
#   Downloading fastparquet-2023.10.1-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (1.7 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.7/1.7 MB 18.6 MB/s eta 0:00:00
# Requirement already satisfied: torch>=2.0.1 in /usr/local/lib/python3.10/dist-packages (from exllamav2==0.0.11) (2.1.0+cu121)
# Requirement already satisfied: safetensors>=0.3.2 in /usr/local/lib/python3.10/dist-packages (from exllamav2==0.0.11) (0.4.1)
# Collecting sentencepiece>=0.1.97 (from exllamav2==0.0.11)
#   Downloading sentencepiece-0.1.99-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (1.3 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.3/1.3 MB 25.7 MB/s eta 0:00:00
# Requirement already satisfied: pygments in /usr/local/lib/python3.10/dist-packages (from exllamav2==0.0.11) (2.16.1)
# Collecting websockets (from exllamav2==0.0.11)
#   Downloading websockets-12.0-cp310-cp310-manylinux_2_5_x86_64.manylinux1_x86_64.manylinux_2_17_x86_64.manylinux2014_x86_64.whl (130 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 130.2/130.2 kB 17.5 MB/s eta 0:00:00
# Requirement already satisfied: regex in /usr/local/lib/python3.10/dist-packages (from exllamav2==0.0.11) (2023.6.3)
# Requirement already satisfied: filelock in /usr/local/lib/python3.10/dist-packages (from torch>=2.0.1->exllamav2==0.0.11) (3.13.1)
# Requirement already satisfied: typing-extensions in /usr/local/lib/python3.10/dist-packages (from torch>=2.0.1->exllamav2==0.0.11) (4.5.0)
# Requirement already satisfied: sympy in /usr/local/lib/python3.10/dist-packages (from torch>=2.0.1->exllamav2==0.0.11) (1.12)
# Requirement already satisfied: networkx in /usr/local/lib/python3.10/dist-packages (from torch>=2.0.1->exllamav2==0.0.11) (3.2.1)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.10/dist-packages (from torch>=2.0.1->exllamav2==0.0.11) (3.1.2)
# Requirement already satisfied: fsspec in /usr/local/lib/python3.10/dist-packages (from torch>=2.0.1->exllamav2==0.0.11) (2023.6.0)
# Requirement already satisfied: triton==2.1.0 in /usr/local/lib/python3.10/dist-packages (from torch>=2.0.1->exllamav2==0.0.11) (2.1.0)
# Requirement already satisfied: numpy>=1.20.3 in /usr/local/lib/python3.10/dist-packages (from fastparquet->exllamav2==0.0.11) (1.23.5)
# Collecting cramjam>=2.3 (from fastparquet->exllamav2==0.0.11)
#   Downloading cramjam-2.7.0-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (1.6 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.6/1.6 MB 31.7 MB/s eta 0:00:00
# Requirement already satisfied: packaging in /usr/local/lib/python3.10/dist-packages (from fastparquet->exllamav2==0.0.11) (23.2)
# Requirement already satisfied: python-dateutil>=2.8.1 in /usr/local/lib/python3.10/dist-packages (from pandas->exllamav2==0.0.11) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.10/dist-packages (from pandas->exllamav2==0.0.11) (2023.3.post1)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.10/dist-packages (from python-dateutil>=2.8.1->pandas->exllamav2==0.0.11) (1.16.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.10/dist-packages (from jinja2->torch>=2.0.1->exllamav2==0.0.11) (2.1.3)
# Requirement already satisfied: mpmath>=0.19 in /usr/local/lib/python3.10/dist-packages (from sympy->torch>=2.0.1->exllamav2==0.0.11) (1.3.0)
# Installing collected packages: sentencepiece, ninja, websockets, cramjam, fastparquet, exllamav2
#   Running setup.py develop for exllamav2
# Successfully installed cramjam-2.7.0 exllamav2-0.0.11 fastparquet-2023.10.1 ninja-1.11.1.1 sentencepiece-0.1.99 websockets-12.0

# %%
from huggingface_hub import notebook_login
notebook_login()
# Out:
# VBox(children=(HTML(value='<center> <img\nsrc=https://huggingface.co/front/assets/huggingface_logo-noborder.sv…

# %%
MODEL_NAME = "SeaLLM-7B-Chat"

"""Download model"""
# !git lfs install
# !git clone https://huggingface.co/SeaLLMs/{MODEL_NAME}
# !mv {MODEL_NAME} base_model
# !rm base_mode/*.bin

"""Quantize model"""
BPW = 2.5

# !mkdir quant_model
# !python exllamav2/convert.py \
    -i base_model \
    -o quant_model \
    -b {BPW}

"""Copy files"""
# !rm -rf quant_model/out_tensor
# !rsync -av --exclude='*.safetensors' --exclude='.*' ./base_model/ ./quant_model/
# Out:
# Git LFS initialized.
# Cloning into 'SeaLLM-7B-Chat'...
# remote: Enumerating objects: 49, done.
# remote: Total 49 (delta 0), reused 0 (delta 0), pack-reused 49
# Unpacking objects: 100% (49/49), 1.38 MiB | 7.01 MiB/s, done.
# Filtering content: 100% (3/3), 4.80 GiB | 10.74 MiB/s, done.
# Encountered 1 file(s) that may not have been copied correctly on Windows:
# 	model-00001-of-00002.safetensors
#
# See: `git lfs help smudge` for more details.
# rm: cannot remove 'base_mode/*.bin': No such file or directory
#  -- Beginning new job
#  -- Input: base_model
#  -- Output: quant_model
#  -- Using default calibration dataset
#  -- Target bits per weight: 4.125 (decoder), 6 (head)
#  -- Max shard size: 8192 MB
#  -- Tokenizing samples (measurement)...
#  -- Token embeddings (measurement)...
#  -- Measuring quantization impact...
#  -- Layer: model.layers.0 (Attention)
#  -- model.layers.0.self_attn.q_proj                    0.05:3b_64g/0.95:2b_64g s4                         2.13 bpw
#  -- model.layers.0.self_attn.q_proj                    0.1:3b_64g/0.9:2b_64g s4                           2.17 bpw
#  -- model.layers.0.self_attn.q_proj                    0.1:4b_128g/0.9:3b_128g s4                         3.16 bpw
#  -- model.layers.0.self_attn.q_proj                    1:4b_128g s4                                       4.03 bpw
#  -- model.layers.0.self_attn.q_proj                    1:4b_64g s4                                        4.06 bpw
#  -- model.layers.0.self_attn.q_proj                    1:4b_32g s4                                        4.13 bpw
#  -- model.layers.0.self_attn.q_proj                    0.1:5b_128g/0.9:4b_128g s4                         4.16 bpw
#  -- model.layers.0.self_attn.q_proj                    0.1:5b_64g/0.9:4b_64g s4                           4.17 bpw
#  -- model.layers.0.self_attn.q_proj                    0.1:5b_32g/0.9:4b_32g s4                           4.23 bpw
#  -- model.layers.0.self_attn.q_proj                    0.1:6b_128g/0.9:5b_128g s4                         5.16 bpw
#  -- model.layers.0.self_attn.q_proj                    0.1:6b_32g/0.9:5b_32g s4                           5.23 bpw
#  -- model.layers.0.self_attn.q_proj                    1:6b_128g s4                                       6.03 bpw
#  -- model.layers.0.self_attn.q_proj                    1:6b_32g s4                                        6.13 bpw
#  -- model.layers.0.self_attn.q_proj                    1:8b_128g s4                                       8.03 bpw
#  -- model.layers.0.self_attn.k_proj                    0.05:3b_64g/0.95:2b_64g s4                         2.13 bpw
#  -- model.layers.0.self_attn.k_proj                    0.1:3b_64g/0.9:2b_64g s4                           2.17 bpw
#  -- model.layers.0.self_attn.k_proj                    0.1:4b_128g/0.9:3b_128g s4                         3.16 bpw
#  -- model.layers.0.self_attn.k_proj                    1:4b_128g s4                                       4.03 bpw
#  -- model.layers.0.self_attn.k_proj                    1:4b_64g s4                                        4.06 bpw
#  -- model.layers.0.self_attn.k_proj                    1:4b_32g s4                                        4.13 bpw
#  -- model.layers.0.self_attn.k_proj                    0.1:5b_128g/0.9:4b_128g s4                         4.16 bpw
#  -- model.layers.0.self_attn.k_proj                    0.1:5b_64g/0.9:4b_64g s4                           4.17 bpw
#  -- model.layers.0.self_attn.k_proj                    0.1:5b_32g/0.9:4b_32g s4                           4.23 bpw
#  -- model.layers.0.self_attn.k_proj                    0.1:6b_128g/0.9:5b_128g s4                         5.16 bpw
#  -- model.layers.0.self_attn.k_proj                    0.1:6b_32g/0.9:5b_32g s4                           5.23 bpw
#  -- model.layers.0.self_attn.k_proj                    1:6b_128g s4                                       6.03 bpw
#  -- model.layers.0.self_attn.k_proj                    1:6b_32g s4                                        6.13 bpw
#  -- model.layers.0.self_attn.k_proj                    1:8b_128g s4                                       8.03 bpw
#  -- model.layers.0.self_attn.v_proj                    0.05:3b_64g/0.95:2b_64g s4                         2.13 bpw
#  -- model.layers.0.self_attn.v_proj                    0.25:3b_64g/0.75:2b_64g s4                         2.31 bpw
#  -- model.layers.0.self_attn.v_proj                    0.1:4b_128g/0.9:3b_128g s4                         3.16 bpw
#  -- model.layers.0.self_attn.v_proj                    0.1:4b_64g/0.9:3b_64g s4                           3.17 bpw
#  -- model.layers.0.self_attn.v_proj                    1:4b_128g s4                                       4.03 bpw
#  -- model.layers.0.self_attn.v_proj                    1:4b_64g s4                                        4.06 bpw
#  -- model.layers.0.self_attn.v_proj                    1:4b_32g s4                                        4.13 bpw
#  -- model.layers.0.self_attn.v_proj                    0.1:5b_64g/0.9:4b_64g s4                           4.17 bpw
#  -- model.layers.0.self_attn.v_proj                    0.1:5b_32g/0.9:4b_32g s4                           4.23 bpw
#  -- model.layers.0.self_attn.v_proj                    1:5b_64g s4                                        5.06 bpw
#  -- model.layers.0.self_attn.v_proj                    1:5b_32g s4                                        5.13 bpw
#  -- model.layers.0.self_attn.v_proj                    1:6b_128g s4                                       6.03 bpw
#  -- model.layers.0.self_attn.v_proj                    1:6b_32g s4                                        6.13 bpw
#  -- model.layers.0.self_attn.v_proj                    1:8b_32g s4                                        8.13 bpw
#  -- model.layers.0.self_attn.v_proj                    1:8b_128g s4                                       8.03 bpw
#  -- model.layers.0.self_attn.o_proj                    0.05:3b_64g/0.95:2b_64g s4                         2.13 bpw
#  -- model.layers.0.self_attn.o_proj                    0.1:3b_64g/0.9:2b_64g s4                           2.17 bpw
#  -- model.layers.0.self_attn.o_proj                    0.1:4b_128g/0.9:3b_128g s4                         3.16 bpw
#  -- model.layers.0.self_attn.o_proj                    1:4b_128g s4                                       4.03 bpw
#  -- model.layers.0.self_attn.o_proj                    1:4b_64g s4                                        4.06 bpw
#  -- model.layers.0.self_attn.o_proj                    1:4b_32g s4                                        4.13 bpw
#  -- model.layers.0.self_attn.o_proj                    0.1:5b_128g/0.9:4b_128g s4                         4.16 bpw
#  -- model.layers.0.self_attn.o_proj                    0.1:5b_64g/0.9:4b_64g s4                           4.17 bpw
#  -- model.layers.0.self_attn.o_proj                    0.1:5b_32g/0.9:4b_32g s4                           4.23 bpw
#  -- model.layers.0.self_attn.o_proj                    0.1:6b_128g/0.9:5b_128g s4                         5.16 bpw
#  -- model.layers.0.self_attn.o_proj                    0.1:6b_32g/0.9:5b_32g s4                           5.23 bpw
#  -- model.layers.0.self_attn.o_proj                    1:6b_128g s4                                       6.03 bpw
#  -- model.layers.0.self_attn.o_proj                    1:6b_32g s4                                        6.13 bpw
#  -- model.layers.0.self_attn.o_proj                    1:8b_128g s4                                       8.03 bpw
#  -- 2.1252 bpw  accuracy: 0.96952486
#  -- 2.2072 bpw  accuracy: 0.97356462
#  -- 2.4181 bpw  accuracy: 0.97815359
#  -- 2.6642 bpw  accuracy: 0.98518264
#  -- 3.1563 bpw  accuracy: 0.98627418
#  -- 3.1603 bpw  accuracy: 0.98721099
#  -- 4.0313 bpw  accuracy: 0.98964053
#  -- 4.0392 bpw  accuracy: 0.99091804
#  -- 4.0784 bpw  accuracy: 0.99191040
#  -- 4.1254 bpw  accuracy: 0.99221218
#  -- 4.1603 bpw  accuracy: 0.99370188
#  -- 4.1858 bpw  accuracy: 0.99391812
#  -- 4.3947 bpw  accuracy: 0.99441403
#  -- 4.4515 bpw  accuracy: 0.99466294
#  -- 5.3751 bpw  accuracy: 0.99661136
#  -- 5.4515 bpw  accuracy: 0.99635851
#  -- 6.0313 bpw  accuracy: 0.99695551
#  -- 6.6254 bpw  accuracy: 0.99681181
#  -- 8.0313 bpw  accuracy: 0.99810922
#  -- Layer: model.layers.0 (MLP)
#  -- model.layers.0.mlp.gate_proj                       0.05:3b_64g/0.95:2b_64g s4                         2.13 bpw
#  -- model.layers.0.mlp.gate_proj                       0.1:3b_64g/0.9:2b_64g s4                           2.17 bpw
#  -- model.layers.0.mlp.gate_proj                       0.1:4b_128g/0.9:3b_128g s4                         3.16 bpw
#  -- model.layers.0.mlp.gate_proj                       0.1:4b_32g/0.9:3b_32g s4                           3.23 bpw
#  -- model.layers.0.mlp.gate_proj                       1:4b_128g s4                                       4.03 bpw
#  -- model.layers.0.mlp.gate_proj                       1:4b_32g s4                                        4.13 bpw
#  -- model.layers.0.mlp.gate_proj                       0.1:5b_128g/0.9:4b_128g s4                         4.16 bpw
#  -- model.layers.0.mlp.gate_proj                       0.1:5b_32g/0.9:4b_32g s4                           4.23 bpw
#  -- model.layers.0.mlp.gate_proj                       0.1:6b_128g/0.9:5b_128g s4                         5.16 bpw
#  -- model.layers.0.mlp.gate_proj                       0.1:6b_32g/0.9:5b_32g s4                           5.23 bpw
#  -- model.layers.0.mlp.gate_proj                       1:6b_128g s4                                       6.03 bpw
#  -- model.layers.0.mlp.gate_proj                       0.1:8b_128g/0.9:6b_128g s4                         6.28 bpw
#  -- model.layers.0.mlp.gate_proj                       1:8b_128g s4                                       8.03 bpw
#  -- model.layers.0.mlp.up_proj                         0.05:3b_64g/0.95:2b_64g s4                         2.13 bpw
#  -- model.layers.0.mlp.up_proj                         0.25:3b_64g/0.75:2b_64g s4                         2.31 bpw
#  -- model.layers.0.mlp.up_proj                         0.3:3b_64g/0.7:2b_64g s4                           2.38 bpw
#  -- model.layers.0.mlp.up_proj                         0.25:4b_128g/0.75:3b_128g s4                       3.28 bpw
#  -- model.layers.0.mlp.up_proj                         0.25:4b_32g/0.75:3b_32g s4                         3.38 bpw
#  -- model.layers.0.mlp.up_proj                         1:4b_32g s4                                        4.13 bpw
#  -- model.layers.0.mlp.up_proj                         0.25:5b_128g/0.75:4b_128g s4                       4.28 bpw
#  -- model.layers.0.mlp.up_proj                         0.25:5b_32g/0.75:4b_32g s4                         4.38 bpw
#  -- model.layers.0.mlp.up_proj                         0.25:6b_128g/0.75:5b_128g s4                       5.28 bpw
#  -- model.layers.0.mlp.up_proj                         0.25:6b_32g/0.75:5b_32g s4                         5.38 bpw
#  -- model.layers.0.mlp.up_proj                         1:6b_128g s4                                       6.03 bpw
#  -- model.layers.0.mlp.up_proj                         0.1:8b_128g/0.9:6b_128g s4                         6.28 bpw
#  -- model.layers.0.mlp.up_proj                         1:8b_128g s4                                       8.03 bpw
#  -- model.layers.0.mlp.down_proj                       0.05:6b_32g/0.2:3b_64g/0.75:2b_64g s4              2.48 bpw
#  -- model.layers.0.mlp.down_proj                       0.05:5b_32g/0.95:3b_32g s4                         3.23 bpw
#  -- model.layers.0.mlp.down_proj                       0.05:5b_32g/0.95:4b_32g s4                         4.18 bpw
#  -- model.layers.0.mlp.down_proj                       0.05:8b_32g/0.1:4b_128g/0.85:3b_128g s4            3.40 bpw
#  -- model.layers.0.mlp.down_proj                       0.05:8b_32g/0.1:4b_32g/0.85:3b_32g s4              3.49 bpw
#  -- model.layers.0.mlp.down_proj                       0.05:8b_32g/0.95:4b_128g s4                        4.25 bpw
#  -- model.layers.0.mlp.down_proj                       0.05:8b_32g/0.95:4b_32g s4                         4.33 bpw
#  -- model.layers.0.mlp.down_proj                       0.05:8b_32g/0.1:5b_128g/0.85:4b_128g s4            4.35 bpw
#  -- model.layers.0.mlp.down_proj                       0.05:8b_32g/0.1:5b_32g/0.85:4b_32g s4              4.44 bpw
#  -- model.layers.0.mlp.down_proj                       0.05:8b_32g/0.1:6b_128g/0.85:5b_128g s4            5.30 bpw
#  -- model.layers.0.mlp.down_proj                       0.05:8b_32g/0.1:6b_32g/0.85:5b_32g s4              5.38 bpw
#  -- model.layers.0.mlp.down_proj                       0.05:8b_32g/0.95:6b_128g s4                        6.14 bpw
#  -- model.layers.0.mlp.down_proj                       0.15:8b_128g/0.85:6b_128g s4                       6.33 bpw
#  -- model.layers.0.mlp.down_proj                       1:8b_128g s4                                       8.03 bpw
#  -- 2.2430 bpw  accuracy: 0.93592483
#  -- 2.3211 bpw  accuracy: 0.93781424
#  -- 2.5923 bpw  accuracy: 0.95062983
#  -- 2.9082 bpw  accuracy: 0.95468658
#  -- 3.2801 bpw  accuracy: 0.97052085
#  -- 3.3635 bpw  accuracy: 0.97246939
#  -- 3.6159 bpw  accuracy: 0.97796845
#  -- 4.1341 bpw  accuracy: 0.98438293
#  -- 4.1950 bpw  accuracy: 0.98578799
#  -- 4.2627 bpw  accuracy: 0.98512131
#  -- 4.3461 bpw  accuracy: 0.98670524
#  -- 5.2452 bpw  accuracy: 0.99230677
#  -- 5.3286 bpw  accuracy: 0.99245280
#  -- 6.0679 bpw  accuracy: 0.99521309
#  -- 6.2987 bpw  accuracy: 0.99563664
#  -- 6.8646 bpw  accuracy: 0.99643403
#  -- 8.0313 bpw  accuracy: 0.99720126
#  -- Layer: model.layers.1 (Attention)
#  -- model.layers.1.self_attn.q_proj                    0.05:3b_64g/0.95:2b_64g s4                         2.13 bpw
#  -- model.layers.1.self_attn.q_proj                    0.1:3b_64g/0.9:2b_64g s4                           2.17 bpw
#  -- model.layers.1.self_attn.q_proj                    0.1:4b_128g/0.9:3b_128g s4                         3.16 bpw
#  -- model.layers.1.self_attn.q_proj                    1:4b_128g s4                                       4.03 bpw
#  -- model.layers.1.self_attn.q_proj                    1:4b_64g s4                                        4.06 bpw
#  -- model.layers.1.self_attn.q_proj                    1:4b_32g s4                                        4.13 bpw
#  -- model.layers.1.self_attn.q_proj                    0.1:5b_128g/0.9:4b_128g s4                         4.16 bpw
#  -- model.layers.1.self_attn.q_proj                    0.1:5b_64g/0.9:4b_64g s4                           4.17 bpw
#  -- model.layers.1.self_attn.q_proj                    0.1:5b_32g/0.9:4b_32g s4                           4.23 bpw
#  -- model.layers.1.self_attn.q_proj                    0.1:6b_128g/0.9:5b_128g s4                         5.16 bpw
#  -- model.layers.1.self_attn.q_proj                    0.1:6b_32g/0.9:5b_32g s4                           5.23 bpw
#  -- model.layers.1.self_attn.q_proj                    1:6b_128g s4                                       6.03 bpw
#  -- model.layers.1.self_attn.q_proj                    1:6b_32g s4                                        6.13 bpw
#  -- model.layers.1.self_attn.q_proj                    1:8b_128g s4                                       8.03 bpw
#  -- model.layers.1.self_attn.k_proj                    0.05:3b_64g/0.95:2b_64g s4                         2.13 bpw
#  -- model.layers.1.self_attn.k_proj                    0.1:3b_64g/0.9:2b_64g s4                           2.17 bpw
#  -- model.layers.1.self_attn.k_proj                    0.1:4b_128g/0.9:3b_128g s4                         3.16 bpw
#  -- model.layers.1.self_attn.k_proj                    1:4b_128g s4                                       4.03 bpw
#  -- model.layers.1.self_attn.k_proj                    1:4b_64g s4                                        4.06 bpw
#  -- model.layers.1.self_attn.k_proj                    1:4b_32g s4                                        4.13 bpw
#  -- model.layers.1.self_attn.k_proj                    0.1:5b_128g/0.9:4b_128g s4                         4.16 bpw
#  -- model.layers.1.self_attn.k_proj                    0.1:5b_64g/0.9:4b_64g s4                           4.17 bpw
#  -- model.layers.1.self_attn.k_proj                    0.1:5b_32g/0.9:4b_32g s4                           4.23 bpw
#  -- model.layers.1.self_attn.k_proj                    0.1:6b_128g/0.9:5b_128g s4                         5.16 bpw
#  -- model.layers.1.self_attn.k_proj                    0.1:6b_32g/0.9:5b_32g s4                           5.23 bpw
#  -- model.layers.1.self_attn.k_proj                    1:6b_128g s4                                       6.03 bpw
#  -- model.layers.1.self_attn.k_proj                    1:6b_32g s4                                        6.13 bpw
#  -- model.layers.1.self_attn.k_proj                    1:8b_128g s4                                       8.03 bpw
#  -- model.layers.1.self_attn.v_proj                    0.05:3b_64g/0.95:2b_64g s4                         2.13 bpw
#  -- model.layers.1.self_attn.v_proj                    0.25:3b_64g/0.75:2b_64g s4                         2.31 bpw
#  -- model.layers.1.self_attn.v_proj                    0.1:4b_128g/0.9:3b_128g s4                         3.16 bpw
#  -- model.layers.1.self_attn.v_proj                    0.1:4b_64g/0.9:3b_64g s4                           3.17 bpw
#  -- model.layers.1.self_attn.v_proj                    1:4b_128g s4                                       4.03 bpw
#  -- model.layers.1.self_attn.v_proj                    1:4b_64g s4                                        4.06 bpw
#  -- model.layers.1.self_attn.v_proj                    1:4b_32g s4                                        4.13 bpw
#  -- model.layers.1.self_attn.v_proj                    0.1:5b_64g/0.9:4b_64g s4                           4.17 bpw
#  -- model.layers.1.self_attn.v_proj                    0.1:5b_32g/0.9:4b_32g s4                           4.23 bpw
#  -- model.layers.1.self_attn.v_proj                    1:5b_64g s4                                        5.06 bpw
#  -- model.layers.1.self_attn.v_proj                    1:5b_32g s4                                        5.13 bpw
#  -- model.layers.1.self_attn.v_proj                    1:6b_128g s4                                       6.03 bpw
#  -- model.layers.1.self_attn.v_proj                    1:6b_32g s4                                        6.13 bpw
#  -- model.layers.1.self_attn.v_proj                    1:8b_32g s4                                        8.13 bpw
#  -- model.layers.1.self_attn.v_proj                    1:8b_128g s4                                       8.03 bpw
#  -- model.layers.1.self_attn.o_proj                    0.05:3b_64g/0.95:2b_64g s4                         2.13 bpw
#  -- model.layers.1.self_attn.o_proj                    0.1:3b_64g/0.9:2b_64g s4                           2.17 bpw
#  -- model.layers.1.self_attn.o_proj                    0.1:4b_128g/0.9:3b_128g s4                         3.16 bpw
#  -- model.layers.1.self_attn.o_proj                    1:4b_128g s4                                       4.03 bpw
#  -- model.layers.1.self_attn.o_proj                    1:4b_64g s4                                        4.06 bpw
#  -- model.layers.1.self_attn.o_proj                    1:4b_32g s4                                        4.13 bpw
#  -- model.layers.1.self_attn.o_proj                    0.1:5b_128g/0.9:4b_128g s4                         4.16 bpw
#  -- model.layers.1.self_attn.o_proj                    0.1:5b_64g/0.9:4b_64g s4                           4.17 bpw
#  -- model.layers.1.self_attn.o_proj                    0.1:5b_32g/0.9:4b_32g s4                           4.23 bpw
#  -- model.layers.1.self_attn.o_proj                    0.1:6b_128g/0.9:5b_128g s4                         5.16 bpw
#  -- model.layers.1.self_attn.o_proj                    0.1:6b_32g/0.9:5b_32g s4                           5.23 bpw
#  -- model.layers.1.self_attn.o_proj                    1:6b_128g s4                                       6.03 bpw
#  -- model.layers.1.self_attn.o_proj                    1:6b_32g s4                                        6.13 bpw
#  -- model.layers.1.self_attn.o_proj                    1:8b_128g s4                                       8.03 bpw
#  -- 2.1252 bpw  accuracy: 0.91172802
#  -- 2.2072 bpw  accuracy: 0.91994947
#  -- 2.4181 bpw  accuracy: 0.92820203
#  -- 2.6642 bpw  accuracy: 0.95495623
#  -- 3.1563 bpw  accuracy: 0.96020699
#  -- 3.1603 bpw  accuracy: 0.96081680
#  -- 4.0313 bpw  accuracy: 0.97407019
#  -- 4.0392 bpw  accuracy: 0.97494918
#  -- 4.0784 bpw  accuracy: 0.97660458
#  -- 4.1254 bpw  accuracy: 0.97770447
#  -- 4.1603 bpw  accuracy: 0.98001164
#  -- 4.1858 bpw  accuracy: 0.98070127
#  -- 4.3947 bpw  accuracy: 0.98241293
#  -- 4.4515 bpw  accuracy: 0.98298037
#  -- 5.3751 bpw  accuracy: 0.99002194
#  -- 5.4515 bpw  accuracy: 0.98953676
#  -- 6.0313 bpw  accuracy: 0.99214405
#  -- 6.6254 bpw  accuracy: 0.99150145
#  -- 8.0313 bpw  accuracy: 0.99471301
#  -- Layer: model.layers.1 (MLP)
#  -- model.layers.1.mlp.gate_proj                       0.05:3b_64g/0.95:2b_64g s4                         2.13 bpw
#  -- model.layers.1.mlp.gate_proj                       0.1:3b_64g/0.9:2b_64g s4                           2.17 bpw
#  -- model.layers.1.mlp.gate_proj                       0.1:4b_128g/0.9:3b_128g s4                         3.16 bpw
#  -- model.layers.1.mlp.gate_proj                       0.1:4b_32g/0.9:3b_32g s4                           3.23 bpw
#  -- model.layers.1.mlp.gate_proj                       1:4b_128g s4                                       4.03 bpw
#  -- model.layers.1.mlp.gate_proj                       1:4b_32g s4                                        4.13 bpw
#  -- model.layers.1.mlp.gate_proj                       0.1:5b_128g/0.9:4b_128g s4                         4.16 bpw
#  -- model.layers.1.mlp.gate_proj                       0.1:5b_32g/0.9:4b_32g s4                           4.23 bpw
#  -- model.layers.1.mlp.gate_proj                       0.1:6b_128g/0.9:5b_128g s4                         5.16 bpw
#  -- model.layers.1.mlp.gate_proj                       0.1:6b_32g/0.9:5b_32g s4                           5.23 bpw
#  -- model.layers.1.mlp.gate_proj                       1:6b_128g s4                                       6.03 bpw
#  -- model.layers.1.mlp.gate_proj                       0.1:8b_128g/0.9:6b_128g s4                         6.28 bpw
#  -- model.layers.1.mlp.gate_proj                       1:8b_128g s4                                       8.03 bpw
#  -- model.layers.1.mlp.up_proj                         0.05:3b_64g/0.95:2b_64g s4                         2.13 bpw
#  -- model.layers.1.mlp.up_proj                         0.25:3b_64g/0.75:2b_64g s4                         2.31 bpw
#  -- model.layers.1.mlp.up_proj                         0.3:3b_64g/0.7:2b_64g s4                           2.38 bpw
#  -- model.layers.1.mlp.up_proj                         0.25:4b_128g/0.75:3b_128g s4                       3.28 bpw
#  -- model.layers.1.mlp.up_proj                         0.25:4b_32g/0.75:3b_32g s4                         3.38 bpw
#  -- model.layers.1.mlp.up_proj                         1:4b_32g s4                                        4.13 bpw
#  -- model.layers.1.mlp.up_proj                         0.25:5b_128g/0.75:4b_128g s4                       4.28 bpw
#  -- model.layers.1.mlp.up_proj                         0.25:5b_32g/0.75:4b_32g s4                         4.38 bpw
#  -- model.layers.1.mlp.up_proj                         0.25:6b_128g/0.75:5b_128g s4                       5.28 bpw
#  -- model.layers.1.mlp.up_proj                         0.25:6b_32g/0.75:5b_32g s4                         5.38 bpw
#  -- model.layers.1.mlp.up_proj                         1:6b_128g s4                                       6.03 bpw
#  -- model.layers.1.mlp.up_proj                         0.1:8b_128g/0.9:6b_128g s4                         6.28 bpw
#  -- model.layers.1.mlp.up_proj                         1:8b_128g s4                                       8.03 bpw
#  -- model.layers.1.mlp.down_proj                       0.05:6b_32g/0.2:3b_64g/0.75:2b_64g s4              2.48 bpw
#  -- model.layers.1.mlp.down_proj                       0.05:5b_32g/0.95:3b_32g s4                         3.23 bpw
#  -- model.layers.1.mlp.down_proj                       0.05:5b_32g/0.95:4b_32g s4                         4.18 bpw
#  -- model.layers.1.mlp.down_proj                       0.05:8b_32g/0.1:4b_128g/0.85:3b_128g s4            3.40 bpw
#  -- model.layers.1.mlp.down_proj                       0.05:8b_32g/0.1:4b_32g/0.85:3b_32g s4              3.49 bpw
#  -- model.layers.1.mlp.down_proj                       0.05:8b_32g/0.95:4b_128g s4                        4.25 bpw
#  -- model.layers.1.mlp.down_proj                       0.05:8b_32g/0.95:4b_32g s4                         4.33 bpw
#  -- model.layers.1.mlp.down_proj                       0.05:8b_32g/0.1:5b_128g/0.85:4b_128g s4            4.35 bpw
#  -- model.layers.1.mlp.down_proj                       0.05:8b_32g/0.1:5b_32g/0.85:4b_32g s4              4.44 bpw
#  -- model.layers.1.mlp.down_proj                       0.05:8b_32g/0.1:6b_128g/0.85:5b_128g s4            5.30 bpw
#  -- model.layers.1.mlp.down_proj                       0.05:8b_32g/0.1:6b_32g/0.85:5b_32g s4              5.38 bpw
#  -- model.layers.1.mlp.down_proj                       0.05:8b_32g/0.95:6b_128g s4                        6.14 bpw
#  -- model.layers.1.mlp.down_proj                       0.15:8b_128g/0.85:6b_128g s4                       6.33 bpw
#  -- model.layers.1.mlp.down_proj                       1:8b_128g s4                                       8.03 bpw
#  -- 2.2430 bpw  accuracy: 0.94331598
#  -- 2.3211 bpw  accuracy: 0.94904298
#  -- 2.5923 bpw  accuracy: 0.95317924
#  -- 2.9082 bpw  accuracy: 0.95433831
#  -- 3.2801 bpw  accuracy: 0.98016697
#  -- 3.3635 bpw  accuracy: 0.98351860
#  -- 3.6159 bpw  accuracy: 0.98505461
#  -- 4.1341 bpw  accuracy: 0.98711449
#  -- 4.1950 bpw  accuracy: 0.98727566
#  -- 4.2627 bpw  accuracy: 0.98805493
#  -- 4.3461 bpw  accuracy: 0.98800939
#  -- 5.2452 bpw  accuracy: 0.98985738
#  -- 5.3286 bpw  accuracy: 0.98975104
#  -- 6.0679 bpw  accuracy: 0.99031377
#  -- 6.2987 bpw  accuracy: 0.99008393
#  -- 6.8646 bpw  accuracy: 0.99015939
#  -- 8.0313 bpw  accuracy: 0.99025267
#  -- Layer: model.layers.2 (Attention)
#  -- model.layers.2.self_attn.q_proj                    0.05:3b_64g/0.95:2b_64g s4                         2.13 bpw
#  -- model.layers.2.self_attn.q_proj                    0.1:3b_64g/0.9:2b_64g s4                           2.17 bpw
#  -- model.layers.2.self_attn.q_proj                    0.1:4b_128g/0.9:3b_128g s4                         3.16 bpw
#  -- model.layers.2.self_attn.q_proj                    1:4b_128g s4                                       4.03 bpw
#  -- model.layers.2.self_attn.q_proj                    1:4b_64g s4                                        4.06 bpw
#  -- model.layers.2.self_attn.q_proj                    1:4b_32g s4                                        4.13 bpw
#  -- model.layers.2.self_attn.q_proj                    0.1:5b_128g/0.9:4b_128g s4                         4.16 bpw
#  -- model.layers.2.self_attn.q_proj                    0.1:5b_64g/0.9:4b_64g s4                           4.17 bpw
#  -- model.layers.2.self_attn.q_proj                    0.1:5b_32g/0.9:4b_32g s4                           4.23 bpw
#  -- model.layers.2.self_attn.q_proj                    0.1:6b_128g/0.9:5b_128g s4                         5.16 bpw
#  -- model.layers.2.self_attn.q_proj                    0.1:6b_32g/0.9:5b_32g s4                           5.23 bpw
#  -- model.layers.2.self_attn.q_proj                    1:6b_128g s4                                       6.03 bpw
#  -- model.layers.2.self_attn.q_proj                    1:6b_32g s4                                        6.13 bpw
#  -- model.layers.2.self_attn.q_proj                    1:8b_128g s4                                       8.03 bpw
#  -- model.layers.2.self_attn.k_proj                    0.05:3b_64g/0.95:2b_64g s4                         2.13 bpw
#  -- model.layers.2.self_attn.k_proj                    0.1:3b_64g/0.9:2b_64g s4                           2.17 bpw
#  -- model.layers.2.self_attn.k_proj                    0.1:4b_128g/0.9:3b_128g s4                         3.16 bpw
#  -- model.layers.2.self_attn.k_proj                    1:4b_128g s4                                       4.03 bpw
#  -- model.layers.2.self_attn.k_proj                    1:4b_64g s4                                        4.06 bpw
#  -- model.layers.2.self_attn.k_proj                    1:4b_32g s4                                        4.13 bpw
#  -- model.layers.2.self_attn.k_proj                    0.1:5b_128g/0.9:4b_128g s4                         4.16 bpw
#  -- model.layers.2.self_attn.k_proj                    0.1:5b_64g/0.9:4b_64g s4                           4.17 bpw
#  -- model.layers.2.self_attn.k_proj                    0.1:5b_32g/0.9:4b_32g s4                           4.23 bpw
#  -- model.layers.2.self_attn.k_proj                    0.1:6b_128g/0.9:5b_128g s4                         5.16 bpw
#  -- model.layers.2.self_attn.k_proj                    0.1:6b_32g/0.9:5b_32g s4                           5.23 bpw
#  -- model.layers.2.self_attn.k_proj                    1:6b_128g s4                                       6.03 bpw
#  -- model.layers.2.self_attn.k_proj                    1:6b_32g s4                                        6.13 bpw
#  -- model.layers.2.self_attn.k_proj                    1:8b_128g s4                                       8.03 bpw
#  -- model.layers.2.self_attn.v_proj                    0.05:3b_64g/0.95:2b_64g s4                         2.13 bpw
#  -- model.layers.2.self_attn.v_proj                    0.25:3b_64g/0.75:2b_64g s4                         2.31 bpw
#  -- model.layers.2.self_attn.v_proj                    0.1:4b_128g/0.9:3b_128g s4                         3.16 bpw
#  -- model.layers.2.self_attn.v_proj                    0.1:4b_64g/0.9:3b_64g s4                           3.17 bpw
#  -- model.layers.2.self_attn.v_proj                    1:4b_128g s4                                       4.03 bpw
#  -- model.layers.2.self_attn.v_proj                    1:4b_64g s4                                        4.06 bpw
#  -- model.layers.2.self_attn.v_proj                    1:4b_32g s4                                        4.13 bpw
#  -- model.layers.2.self_attn.v_proj                    0.1:5b_64g/0.9:4b_64g s4                           4.17 bpw
#  -- model.layers.2.self_attn.v_proj                    0.1:5b_32g/0.9:4b_32g s4                           4.23 bpw
#  -- model.layers.2.self_attn.v_proj                    1:5b_64g s4                                        5.06 bpw
#  -- model.layers.2.self_attn.v_proj                    1:5b_32g s4                                        5.13 bpw
#  -- model.layers.2.self_attn.v_proj                    1:6b_128g s4                                       6.03 bpw
#  -- model.layers.2.self_attn.v_proj                    1:6b_32g s4                                        6.13 bpw
#  -- model.layers.2.self_attn.v_proj                    1:8b_32g s4                                        8.13 bpw
#  -- model.layers.2.self_attn.v_proj                    1:8b_128g s4                                       8.03 bpw
#  -- model.layers.2.self_attn.o_proj                    0.05:3b_64g/0.95:2b_64g s4                         2.13 bpw
#  -- model.layers.2.self_attn.o_proj                    0.1:3b_64g/0.9:2b_64g s4                           2.17 bpw
#  -- model.layers.2.self_attn.o_proj                    0.1:4b_128g/0.9:3b_128g s4                         3.16 bpw
#  -- model.layers.2.self_attn.o_proj                    1:4b_128g s4                                       4.03 bpw
#  -- model.layers.2.self_attn.o_proj                    1:4b_64g s4                                        4.06 bpw
#  -- model.layers.2.self_attn.o_proj                    1:4b_32g s4                                        4.13 bpw
#  -- model.layers.2.self_attn.o_proj                    0.1:5b_128g/0.9:4b_128g s4                         4.16 bpw
#  -- model.layers.2.self_attn.o_proj                    0.1:5b_64g/0.9:4b_64g s4                           4.17 bpw
#  -- model.layers.2.self_attn.o_proj                    0.1:5b_32g/0.9:4b_32g s4                           4.23 bpw
#  -- model.layers.2.self_attn.o_proj                    0.1:6b_128g/0.9:5b_128g s4                         5.16 bpw
#  -- model.layers.2.self_attn.o_proj                    0.1:6b_32g/0.9:5b_32g s4                           5.23 bpw
#  -- model.layers.2.self_attn.o_proj                    1:6b_128g s4                                       6.03 bpw
#  -- model.layers.2.self_attn.o_proj                    1:6b_32g s4                                        6.13 bpw
#  -- model.layers.2.self_attn.o_proj                    1:8b_128g s4                                       8.03 bpw
#  -- 2.1252 bpw  accuracy: 0.97945303
#  -- 2.2072 bpw  accuracy: 0.98030680
#  -- 2.4181 bpw  accuracy: 0.98417407
#  -- 2.6642 bpw  accuracy: 0.98920101
#  -- 3.1563 bpw  accuracy: 0.98978978
#  -- 3.1603 bpw  accuracy: 0.98997134
#  -- 4.0313 bpw  accuracy: 0.99431235
#  -- 4.0392 bpw  accuracy: 0.99447662
#  -- 4.0784 bpw  accuracy: 0.99494189
#  -- 4.1254 bpw  accuracy: 0.99513018
#  -- 4.1603 bpw  accuracy: 0.99476236
#  -- 4.1858 bpw  accuracy: 0.99512011
#  -- 4.3947 bpw  accuracy: 0.99604332
#  -- 4.4515 bpw  accuracy: 0.99633795
#  -- 5.3751 bpw  accuracy: 0.99781585
#  -- 5.4515 bpw  accuracy: 0.99795824
#  -- 6.0313 bpw  accuracy: 0.99838448
#  -- 6.6254 bpw  accuracy: 0.99860740
#  -- 8.0313 bpw  accuracy: 0.99911833
#  -- Layer: model.layers.2 (MLP)
#  -- model.layers.2.mlp.gate_proj                       0.05:3b_64g/0.95:2b_64g s4                         2.13 bpw
#  -- model.layers.2.mlp.gate_proj                       0.1:3b_64g/0.9:2b_64g s4                           2.17 bpw
#  -- model.layers.2.mlp.gate_proj                       0.1:4b_128g/0.9:3b_128g s4                         3.16 bpw
#  -- model.layers.2.mlp.gate_proj                       0.1:4b_32g/0.9:3b_32g s4                           3.23 bpw
#  -- model.layers.2.mlp.gate_proj                       1:4b_128g s4                                       4.03 bpw
#  -- model.layers.2.mlp.gate_proj                       1:4b_32g s4                                        4.13 bpw
#  -- model.layers.2.mlp.gate_proj                       0.1:5b_128g/0.9:4b_128g s4                         4.16 bpw
#  -- model.layers.2.mlp.gate_proj                       0.1:5b_32g/0.9:4b_32g s4                           4.23 bpw
#  -- model.layers.2.mlp.gate_proj                       0.1:6b_128g/0.9:5b_128g s4                         5.16 bpw
#  -- model.layers.2.mlp.gate_proj                       0.1:6b_32g/0.9:5b_32g s4                           5.23 bpw
#  -- model.layers.2.mlp.gate_proj                       1:6b_128g s4                                       6.03 bpw
#  -- model.layers.2.mlp.gate_proj                       0.1:8b_128g/0.9:6b_128g s4                         6.28 bpw
#  -- model.layers.2.mlp.gate_proj                       1:8b_128g s4                                       8.03 bpw
#  -- model.layers.2.mlp.up_proj                         0.05:3b_64g/0.95:2b_64g s4                         2.13 bpw
#  -- model.layers.2.mlp.up_proj                         0.25:3b_64g/0.75:2b_64g s4                         2.31 bpw
#  -- model.layers.2.mlp.up_proj                         0.3:3b_64g/0.7:2b_64g s4                           2.38 bpw
#  -- model.layers.2.mlp.up_proj                         0.25:4b_128g/0.75:3b_128g s4                       3.28 bpw
#  -- model.layers.2.mlp.up_proj                         0.25:4b_32g/0.75:3b_32g s4                         3.38 bpw
#  -- model.layers.2.mlp.up_proj                         1:4b_32g s4                                        4.13 bpw
#  -- model.layers.2.mlp.up_proj                         0.25:5b_128g/0.75:4b_128g s4                       4.28 bpw
#  -- model.layers.2.mlp.up_proj                         0.25:5b_32g/0.75:4b_32g s4                         4.38 bpw
#  -- model.layers.2.mlp.up_proj                         0.25:6b_128g/0.75:5b_128g s4                       5.28 bpw
#  -- model.layers.2.mlp.up_proj                         0.25:6b_32g/0.75:5b_32g s4                         5.38 bpw
#  -- model.layers.2.mlp.up_proj                         1:6b_128g s4                                       6.03 bpw
#  -- model.layers.2.mlp.up_proj                         0.1:8b_128g/0.9:6b_128g s4                         6.28 bpw
#  -- model.layers.2.mlp.up_proj                         1:8b_128g s4                                       8.03 bpw
#  -- model.layers.2.mlp.down_proj                       0.05:6b_32g/0.2:3b_64g/0.75:2b_64g s4              2.48 bpw
#  -- model.layers.2.mlp.down_proj                       0.05:5b_32g/0.95:3b_32g s4                         3.23 bpw
#  -- model.layers.2.mlp.down_proj                       0.05:5b_32g/0.95:4b_32g s4                         4.18 bpw
#  -- model.layers.2.mlp.down_proj                       0.05:8b_32g/0.1:4b_128g/0.85:3b_128g s4            3.40 bpw
#  -- model.layers.2.mlp.down_proj                       0.05:8b_32g/0.1:4b_32g/0.85:3b_32g s4              3.49 bpw
#  -- model.layers.2.mlp.down_proj                       0.05:8b_32g/0.95:4b_128g s4                        4.25 bpw
#  -- model.layers.2.mlp.down_proj                       0.05:8b_32g/0.95:4b_32g s4                         4.33 bpw
#  -- model.layers.2.mlp.down_proj                       0.05:8b_32g/0.1:5b_128g/0.85:4b_128g s4            4.35 bpw
#  -- model.layers.2.mlp.down_proj                       0.05:8b_32g/0.1:5b_32g/0.85:4b_32g s4              4.44 bpw
#  -- model.layers.2.mlp.down_proj                       0.05:8b_32g/0.1:6b_128g/0.85:5b_128g s4            5.30 bpw
#  -- model.layers.2.mlp.down_proj                       0.05:8b_32g/0.1:6b_32g/0.85:5b_32g s4              5.38 bpw
#  -- model.layers.2.mlp.down_proj                       0.05:8b_32g/0.95:6b_128g s4                        6.14 bpw
#  -- model.layers.2.mlp.down_proj                       0.15:8b_128g/0.85:6b_128g s4                       6.33 bpw
#  -- model.layers.2.mlp.down_proj                       1:8b_128g s4                                       8.03 bpw
#  -- 2.2430 bpw  accuracy: 0.98716402
#  -- 2.3211 bpw  accuracy: 0.98742908
#  -- 2.5923 bpw  accuracy: 0.98993295
#  -- 2.9082 bpw  accuracy: 0.99069130
#  -- 3.2801 bpw  accuracy: 0.99362814
#  -- 3.3635 bpw  accuracy: 0.99413776
#  -- 3.6159 bpw  accuracy: 0.99517047
#  -- 4.1341 bpw  accuracy: 0.99671990
#  -- 4.1950 bpw  accuracy: 0.99704248
#  -- 4.2627 bpw  accuracy: 0.99676394
#  -- 4.3461 bpw  accuracy: 0.99717808
#  -- 5.2452 bpw  accuracy: 0.99835664
#  -- 5.3286 bpw  accuracy: 0.99851763
#  -- 6.0679 bpw  accuracy: 0.99905169
#  -- 6.2987 bpw  accuracy: 0.99909955
#  -- 6.8646 bpw  accuracy: 0.99925971
#  -- 8.0313 bpw  accuracy: 0.99949455
#  -- Layer: model.layers.3 (Attention)
#  -- model.layers.3.self_attn.q_proj                    0.05:3b_64g/0.95:2b_64g s4                         2.13 bpw
#  -- model.layers.3.self_attn.q_proj                    0.1:3b_64g/0.9:2b_64g s4                           2.17 bpw
#  -- model.layers.3.self_attn.q_proj                    0.1:4b_128g/0.9:3b_128g s4                         3.16 bpw
#  -- model.layers.3.self_attn.q_proj                    1:4b_128g s4                                       4.03 bpw
#  -- model.layers.3.self_attn.q_proj                    1:4b_64g s4                                        4.06 bpw
#  -- model.layers.3.self_attn.q_proj                    1:4b_32g s4                                        4.13 bpw
#  -- model.layers.3.self_attn.q_proj                    0.1:5b_128g/0.9:4b_128g s4                         4.16 bpw
#  -- model.layers.3.self_attn.q_proj                    0.1:5b_64g/0.9:4b_64g s4                           4.17 bpw
#  -- model.layers.3.self_attn.q_proj                    0.1:5b_32g/0.9:4b_32g s4                           4.23 bpw
#  -- model.layers.3.self_attn.q_proj                    0.1:6b_128g/0.9:5b_128g s4                         5.16 bpw
#  -- model.layers.3.self_attn.q_proj                    0.1:6b_32g/0.9:5b_32g s4                           5.23 bpw
#  -- model.layers.3.self_attn.q_proj                    1:6b_128g s4                                       6.03 bpw
#  -- model.layers.3.self_attn.q_proj                    1:6b_32g s4                                        6.13 bpw
#  -- model.layers.3.self_attn.q_proj                    1:8b_128g s4                                       8.03 bpw
#  -- model.layers.3.self_attn.k_proj                    0.05:3b_64g/0.95:2b_64g s4                         2.13 bpw
#  -- model.layers.3.self_attn.k_proj                    0.1:3b_64g/0.9:2b_64g s4                           2.17 bpw
#  -- model.layers.3.self_attn.k_proj                    0.1:4b_128g/0.9:3b_128g s4                         3.16 bpw
#  -- model.layers.3.self_attn.k_proj                    1:4b_128g s4                                       4.03 bpw
#  -- model.layers.3.self_attn.k_proj                    1:4b_64g s4                                        4.06 bpw
#  -- model.layers.3.self_attn.k_proj                    1:4b_32g s4                                        4.13 bpw
#  -- model.layers.3.self_attn.k_proj                    0.1:5b_128g/0.9:4b_128g s4                         4.16 bpw
#  -- model.layers.3.self_attn.k_proj                    0.1:5b_64g/0.9:4b_64g s4                           4.17 bpw
#  -- model.layers.3.self_attn.k_proj                    0.1:5b_32g/0.9:4b_32g s4                           4.23 bpw
#  -- model.layers.3.self_attn.k_proj                    0.1:6b_128g/0.9:5b_128g s4                         5.16 bpw
#  -- model.layers.3.self_attn.k_proj                    0.1:6b_32g/0.9:5b_32g s4                           5.23 bpw
#  -- model.layers.3.self_attn.k_proj                    1:6b_128g s4                                       6.03 bpw
#  -- model.layers.3.self_attn.k_proj                    1:6b_32g s4                                        6.13 bpw
#  -- model.layers.3.self_attn.k_proj                    1:8b_128g s4                                       8.03 bpw
#  -- model.layers.3.self_attn.v_proj                    0.05:3b_64g/0.95:2b_64g s4                         2.13 bpw
#  -- model.layers.3.self_attn.v_proj                    0.25:3b_64g/0.75:2b_64g s4                         2.31 bpw
#  -- model.layers.3.self_attn.v_proj                    0.1:4b_128g/0.9:3b_128g s4                         3.16 bpw
#  -- model.layers.3.self_attn.v_proj                    0.1:4b_64g/0.9:3b_64g s4                           3.17 bpw
#  -- model.layers.3.self_attn.v_proj                    1:4b_128g s4                                       4.03 bpw
#  -- model.layers.3.self_attn.v_proj                    1:4b_64g s4                                        4.06 bpw
#  -- model.layers.3.self_attn.v_proj                    1:4b_32g s4                                        4.13 bpw
#  -- model.layers.3.self_attn.v_proj                    0.1:5b_64g/0.9:4b_64g s4                           4.17 bpw
#  -- model.layers.3.self_attn.v_proj                    0.1:5b_32g/0.9:4b_32g s4                           4.23 bpw
#  -- model.layers.3.self_attn.v_proj                    1:5b_64g s4                                        5.06 bpw
#  -- model.layers.3.self_attn.v_proj                    1:5b_32g s4                                        5.13 bpw
#  -- model.layers.3.self_attn.v_proj                    1:6b_128g s4                                       6.03 bpw
#  -- model.layers.3.self_attn.v_proj                    1:6b_32g s4                                        6.13 bpw
#  -- model.layers.3.self_attn.v_proj                    1:8b_32g s4                                        8.13 bpw
#  -- model.layers.3.self_attn.v_proj                    1:8b_128g s4                                       8.03 bpw
#  -- model.layers.3.self_attn.o_proj                    0.05:3b_64g/0.95:2b_64g s4                         2.13 bpw
#  -- model.layers.3.self_attn.o_proj                    0.1:3b_64g/0.9:2b_64g s4                           2.17 bpw
#  -- model.layers.3.self_attn.o_proj                    0.1:4b_128g/0.9:3b_128g s4                         3.16 bpw
#  -- model.layers.3.self_attn.o_proj                    1:4b_128g s4                                       4.03 bpw
#  -- model.layers.3.self_attn.o_proj                    1:4b_64g s4                                        4.06 bpw
#  -- model.layers.3.self_attn.o_proj                    1:4b_32g s4                                        4.13 bpw
#  -- model.layers.3.self_attn.o_proj                    0.1:5b_128g/0.9:4b_128g s4                         4.16 bpw
#  -- model.layers.3.self_attn.o_proj                    0.1:5b_64g/0.9:4b_64g s4                           4.17 bpw
#  -- model.layers.3.self_attn.o_proj                    0.1:5b_32g/0.9:4b_32g s4                           4.23 bpw
#  -- model.layers.3.self_attn.o_proj                    0.1:6b_128g/0.9:5b_128g s4                         5.16 bpw
#  -- model.layers.3.self_attn.o_proj                    0.1:6b_32g/0.9:5b_32g s4                           5.23 bpw
#  -- model.layers.3.self_attn.o_proj                    1:6b_128g s4                                       6.03 bpw
#  -- model.layers.3.self_attn.o_proj                    1:6b_32g s4                                        6.13 bpw
#  -- model.layers.3.self_attn.o_proj                    1:8b_128g s4                                       8.03 bpw
#  -- 2.1252 bpw  accuracy: 0.98480189
#  -- 2.2072 bpw  accuracy: 0.98538369
#  -- 2.4181 bpw  accuracy: 0.98976219
#  -- 2.6642 bpw  accuracy: 0.99212414
#  -- 3.1563 bpw  accuracy: 0.99263620
#  -- 3.1603 bpw  accuracy: 0.99266678
#  -- 4.0313 bpw  accuracy: 0.99587590
#  -- 4.0392 bpw  accuracy: 0.99606049
#  -- 4.0784 bpw  accuracy: 0.99639672
#  -- 4.1254 bpw  accuracy: 0.99649930
#  -- 4.1603 bpw  accuracy: 0.99619591
#  -- 4.1858 bpw  accuracy: 0.99648374
#  -- 4.3947 bpw  accuracy: 0.99736440
#  -- 4.4515 bpw  accuracy: 0.99757820
#  -- 5.3751 bpw  accuracy: 0.99852580
#  -- 5.4515 bpw  accuracy: 0.99865282
#  -- 6.0313 bpw  accuracy: 0.99885762
#  -- 6.6254 bpw  accuracy: 0.99911171
#  -- 8.0313 bpw  accuracy: 0.99943125
#  -- Layer: model.layers.3 (MLP)
#  -- model.layers.3.mlp.gate_proj                       0.05:3b_64g/0.95:2b_64g s4                         2.13 bpw
#  -- model.layers.3.mlp.gate_proj                       0.1:3b_64g/0.9:2b_64g s4                           2.17 bpw
#  -- model.layers.3.mlp.gate_proj                       0.1:4b_128g/0.9:3b_128g s4                         3.16 bpw
#  -- model.layers.3.mlp.gate_proj                       0.1:4b_32g/0.9:3b_32g s4                           3.23 bpw
#  -- model.layers.3.mlp.gate_proj                       1:4b_128g s4                                       4.03 bpw
#  -- model.layers.3.mlp.gate_proj                       1:4b_32g s4                                        4.13 bpw
#  -- model.layers.3.mlp.gate_proj                       0.1:5b_128g/0.9:4b_128g s4                         4.16 bpw
#  -- model.layers.3.mlp.gate_proj                       0.1:5b_32g/0.9:4b_32g s4                           4.23 bpw
#  -- model.layers.3.mlp.gate_proj                       0.1:6b_128g/0.9:5b_128g s4                         5.16 bpw
#  -- model.layers.3.mlp.gate_proj                       0.1:6b_32g/0.9:5b_32g s4                           5.23 bpw
#  -- model.layers.3.mlp.gate_proj                       1:6b_128g s4                                       6.03 bpw
#  -- model.layers.3.mlp.gate_proj                       0.1:8b_128g/0.9:6b_128g s4                         6.28 bpw
#  -- model.layers.3.mlp.gate_proj                       1:8b_128g s4                                       8.03 bpw
#  -- model.layers.3.mlp.up_proj                         0.05:3b_64g/0.95:2b_64g s4                         2.13 bpw
#  -- model.layers.3.mlp.up_proj                         0.25:3b_64g/0.75:2b_64g s4                         2.31 bpw
#  -- model.layers.3.mlp.up_proj                         0.3:3b_64g/0.7:2b_64g s4                           2.38 bpw
#  -- model.layers.3.mlp.up_proj                         0.25:4b_128g/0.75:3b_128g s4                       3.28 bpw
#  -- model.layers.3.mlp.up_proj                         0.25:4b_32g/0.75:3b_32g s4                         3.38 bpw
#  -- model.layers.3.mlp.up_proj                         1:4b_32g s4                                        4.13 bpw
# ...
#  -- Module quantized, rfn_error: 0.006303
#  -- Layer: model.layers.10 (MLP)
#  -- Linear: model.layers.10.mlp.gate_proj -> 1:4b_32g s4, 4.13 bpw
#  -- Linear: model.layers.10.mlp.up_proj -> 1:4b_32g s4, 4.13 bpw
#  -- Linear: model.layers.10.mlp.down_proj -> 0.05:8b_32g/0.95:4b_32g s4, 4.33 bpw
#  -- Module quantized, rfn_error: 0.008776
#  -- Layer: model.layers.11 (Attention)
#  -- Linear: model.layers.11.self_attn.q_proj -> 0.1:5b_32g/0.9:4b_32g s4, 4.23 bpw
#  -- Linear: model.layers.11.self_attn.k_proj -> 0.1:5b_32g/0.9:4b_32g s4, 4.23 bpw
#  -- Linear: model.layers.11.self_attn.v_proj -> 1:5b_32g s4, 5.13 bpw
#  -- Linear: model.layers.11.self_attn.o_proj -> 0.1:5b_32g/0.9:4b_32g s4, 4.23 bpw
#  -- Module quantized, rfn_error: 0.007065
#  -- Layer: model.layers.11 (MLP)
#  -- Linear: model.layers.11.mlp.gate_proj -> 1:4b_32g s4, 4.13 bpw
#  -- Linear: model.layers.11.mlp.up_proj -> 1:4b_32g s4, 4.13 bpw
#  -- Linear: model.layers.11.mlp.down_proj -> 0.05:8b_32g/0.95:4b_32g s4, 4.33 bpw
#  -- Module quantized, rfn_error: 0.009394
#  -- Layer: model.layers.12 (Attention)
#  -- Linear: model.layers.12.self_attn.q_proj -> 0.1:5b_32g/0.9:4b_32g s4, 4.23 bpw
#  -- Linear: model.layers.12.self_attn.k_proj -> 0.1:5b_32g/0.9:4b_32g s4, 4.23 bpw
#  -- Linear: model.layers.12.self_attn.v_proj -> 1:5b_32g s4, 5.13 bpw
#  -- Linear: model.layers.12.self_attn.o_proj -> 0.1:5b_32g/0.9:4b_32g s4, 4.23 bpw
#  -- Module quantized, rfn_error: 0.007333
#  -- Layer: model.layers.12 (MLP)
#  -- Linear: model.layers.12.mlp.gate_proj -> 1:4b_32g s4, 4.13 bpw
#  -- Linear: model.layers.12.mlp.up_proj -> 1:4b_32g s4, 4.13 bpw
#  -- Linear: model.layers.12.mlp.down_proj -> 0.05:8b_32g/0.95:4b_32g s4, 4.33 bpw
#  -- Module quantized, rfn_error: 0.010068
#  -- Layer: model.layers.13 (Attention)
#  -- Linear: model.layers.13.self_attn.q_proj -> 0.1:5b_32g/0.9:4b_32g s4, 4.23 bpw
#  -- Linear: model.layers.13.self_attn.k_proj -> 0.1:5b_32g/0.9:4b_32g s4, 4.23 bpw
#  -- Linear: model.layers.13.self_attn.v_proj -> 1:5b_32g s4, 5.13 bpw
#  -- Linear: model.layers.13.self_attn.o_proj -> 0.1:5b_32g/0.9:4b_32g s4, 4.23 bpw
#  -- Module quantized, rfn_error: 0.007476
#  -- Layer: model.layers.13 (MLP)
#  -- Linear: model.layers.13.mlp.gate_proj -> 1:4b_32g s4, 4.13 bpw
#  -- Linear: model.layers.13.mlp.up_proj -> 1:4b_32g s4, 4.13 bpw
#  -- Linear: model.layers.13.mlp.down_proj -> 0.05:8b_32g/0.95:4b_32g s4, 4.33 bpw
#  -- Module quantized, rfn_error: 0.010787
#  -- Layer: model.layers.14 (Attention)
#  -- Linear: model.layers.14.self_attn.q_proj -> 0.1:5b_32g/0.9:4b_32g s4, 4.23 bpw
#  -- Linear: model.layers.14.self_attn.k_proj -> 0.1:5b_32g/0.9:4b_32g s4, 4.23 bpw
#  -- Linear: model.layers.14.self_attn.v_proj -> 1:5b_32g s4, 5.13 bpw
#  -- Linear: model.layers.14.self_attn.o_proj -> 0.1:5b_32g/0.9:4b_32g s4, 4.23 bpw
#  -- Module quantized, rfn_error: 0.007974
#  -- Layer: model.layers.14 (MLP)
#  -- Linear: model.layers.14.mlp.gate_proj -> 1:4b_32g s4, 4.13 bpw
#  -- Linear: model.layers.14.mlp.up_proj -> 1:4b_32g s4, 4.13 bpw
#  -- Linear: model.layers.14.mlp.down_proj -> 0.05:8b_32g/0.95:4b_32g s4, 4.33 bpw
#  -- Module quantized, rfn_error: 0.011515
#  -- Layer: model.layers.15 (Attention)
#  -- Linear: model.layers.15.self_attn.q_proj -> 0.1:5b_32g/0.9:4b_32g s4, 4.23 bpw
#  -- Linear: model.layers.15.self_attn.k_proj -> 0.1:5b_32g/0.9:4b_32g s4, 4.23 bpw
#  -- Linear: model.layers.15.self_attn.v_proj -> 1:5b_32g s4, 5.13 bpw
#  -- Linear: model.layers.15.self_attn.o_proj -> 0.1:5b_32g/0.9:4b_32g s4, 4.23 bpw
#  -- Module quantized, rfn_error: 0.007976
#  -- Layer: model.layers.15 (MLP)
#  -- Linear: model.layers.15.mlp.gate_proj -> 1:4b_32g s4, 4.13 bpw
#  -- Linear: model.layers.15.mlp.up_proj -> 1:4b_32g s4, 4.13 bpw
#  -- Linear: model.layers.15.mlp.down_proj -> 0.05:8b_32g/0.95:4b_32g s4, 4.33 bpw
#  -- Module quantized, rfn_error: 0.012459
#  -- Layer: model.layers.16 (Attention)
#  -- Linear: model.layers.16.self_attn.q_proj -> 0.1:5b_32g/0.9:4b_32g s4, 4.23 bpw
#  -- Linear: model.layers.16.self_attn.k_proj -> 0.1:5b_32g/0.9:4b_32g s4, 4.23 bpw
#  -- Linear: model.layers.16.self_attn.v_proj -> 1:5b_32g s4, 5.13 bpw
#  -- Linear: model.layers.16.self_attn.o_proj -> 0.1:5b_32g/0.9:4b_32g s4, 4.23 bpw
#  -- Module quantized, rfn_error: 0.008812
#  -- Layer: model.layers.16 (MLP)
#  -- Linear: model.layers.16.mlp.gate_proj -> 1:4b_32g s4, 4.13 bpw
#  -- Linear: model.layers.16.mlp.up_proj -> 1:4b_32g s4, 4.13 bpw
#  -- Linear: model.layers.16.mlp.down_proj -> 0.05:8b_32g/0.95:4b_32g s4, 4.33 bpw
#  -- Module quantized, rfn_error: 0.013565
#  -- Layer: model.layers.17 (Attention)
#  -- Linear: model.layers.17.self_attn.q_proj -> 0.1:5b_32g/0.9:4b_32g s4, 4.23 bpw
#  -- Linear: model.layers.17.self_attn.k_proj -> 0.1:5b_32g/0.9:4b_32g s4, 4.23 bpw
#  -- Linear: model.layers.17.self_attn.v_proj -> 1:5b_32g s4, 5.13 bpw
#  -- Linear: model.layers.17.self_attn.o_proj -> 0.1:5b_32g/0.9:4b_32g s4, 4.23 bpw
#  -- Module quantized, rfn_error: 0.007880
#  -- Layer: model.layers.17 (MLP)
#  -- Linear: model.layers.17.mlp.gate_proj -> 1:4b_32g s4, 4.13 bpw
#  -- Linear: model.layers.17.mlp.up_proj -> 1:4b_32g s4, 4.13 bpw
#  -- Linear: model.layers.17.mlp.down_proj -> 0.05:8b_32g/0.95:4b_32g s4, 4.33 bpw
#  -- Module quantized, rfn_error: 0.014089
#  -- Layer: model.layers.18 (Attention)
#  -- Linear: model.layers.18.self_attn.q_proj -> 0.1:5b_32g/0.9:4b_32g s4, 4.23 bpw
#  -- Linear: model.layers.18.self_attn.k_proj -> 0.1:5b_32g/0.9:4b_32g s4, 4.23 bpw
#  -- Linear: model.layers.18.self_attn.v_proj -> 1:5b_32g s4, 5.13 bpw
#  -- Linear: model.layers.18.self_attn.o_proj -> 0.1:5b_32g/0.9:4b_32g s4, 4.23 bpw
#  -- Module quantized, rfn_error: 0.008031
#  -- Layer: model.layers.18 (MLP)
#  -- Linear: model.layers.18.mlp.gate_proj -> 1:4b_32g s4, 4.13 bpw
#  -- Linear: model.layers.18.mlp.up_proj -> 1:4b_32g s4, 4.13 bpw
#  -- Linear: model.layers.18.mlp.down_proj -> 0.05:8b_32g/0.95:4b_32g s4, 4.33 bpw
#  -- Module quantized, rfn_error: 0.014748
#  -- Layer: model.layers.19 (Attention)
#  -- Linear: model.layers.19.self_attn.q_proj -> 0.1:5b_32g/0.9:4b_32g s4, 4.23 bpw
#  -- Linear: model.layers.19.self_attn.k_proj -> 0.1:5b_32g/0.9:4b_32g s4, 4.23 bpw
#  -- Linear: model.layers.19.self_attn.v_proj -> 1:5b_32g s4, 5.13 bpw
#  -- Linear: model.layers.19.self_attn.o_proj -> 0.1:5b_32g/0.9:4b_32g s4, 4.23 bpw
#  -- Module quantized, rfn_error: 0.007487
#  -- Layer: model.layers.19 (MLP)
#  -- Linear: model.layers.19.mlp.gate_proj -> 0.1:5b_32g/0.9:4b_32g s4, 4.23 bpw
#  -- Linear: model.layers.19.mlp.up_proj -> 0.25:5b_32g/0.75:4b_32g s4, 4.38 bpw
#  -- Linear: model.layers.19.mlp.down_proj -> 0.05:8b_32g/0.1:5b_32g/0.85:4b_32g s4, 4.44 bpw
#  -- Module quantized, rfn_error: 0.014239
#  -- Layer: model.layers.20 (Attention)
#  -- Linear: model.layers.20.self_attn.q_proj -> 0.1:5b_32g/0.9:4b_32g s4, 4.23 bpw
#  -- Linear: model.layers.20.self_attn.k_proj -> 0.1:5b_32g/0.9:4b_32g s4, 4.23 bpw
#  -- Linear: model.layers.20.self_attn.v_proj -> 1:5b_32g s4, 5.13 bpw
#  -- Linear: model.layers.20.self_attn.o_proj -> 0.1:5b_32g/0.9:4b_32g s4, 4.23 bpw
#  -- Module quantized, rfn_error: 0.007614
#  -- Layer: model.layers.20 (MLP)
#  -- Linear: model.layers.20.mlp.gate_proj -> 0.1:5b_32g/0.9:4b_32g s4, 4.23 bpw
#  -- Linear: model.layers.20.mlp.up_proj -> 0.25:5b_32g/0.75:4b_32g s4, 4.38 bpw
#  -- Linear: model.layers.20.mlp.down_proj -> 0.05:8b_32g/0.1:5b_32g/0.85:4b_32g s4, 4.44 bpw
#  -- Module quantized, rfn_error: 0.014599
#  -- Layer: model.layers.21 (Attention)
#  -- Linear: model.layers.21.self_attn.q_proj -> 0.1:5b_32g/0.9:4b_32g s4, 4.23 bpw
#  -- Linear: model.layers.21.self_attn.k_proj -> 0.1:5b_32g/0.9:4b_32g s4, 4.23 bpw
#  -- Linear: model.layers.21.self_attn.v_proj -> 1:5b_32g s4, 5.13 bpw
#  -- Linear: model.layers.21.self_attn.o_proj -> 0.1:5b_32g/0.9:4b_32g s4, 4.23 bpw
#  -- Module quantized, rfn_error: 0.007260
#  -- Layer: model.layers.21 (MLP)
#  -- Linear: model.layers.21.mlp.gate_proj -> 0.1:5b_32g/0.9:4b_32g s4, 4.23 bpw
#  -- Linear: model.layers.21.mlp.up_proj -> 0.25:5b_32g/0.75:4b_32g s4, 4.38 bpw
#  -- Linear: model.layers.21.mlp.down_proj -> 0.05:8b_32g/0.1:5b_32g/0.85:4b_32g s4, 4.44 bpw
#  -- Module quantized, rfn_error: 0.014633
#  -- Layer: model.layers.22 (Attention)
#  -- Linear: model.layers.22.self_attn.q_proj -> 0.1:5b_32g/0.9:4b_32g s4, 4.23 bpw
#  -- Linear: model.layers.22.self_attn.k_proj -> 0.1:5b_32g/0.9:4b_32g s4, 4.23 bpw
#  -- Linear: model.layers.22.self_attn.v_proj -> 1:5b_32g s4, 5.13 bpw
#  -- Linear: model.layers.22.self_attn.o_proj -> 0.1:5b_32g/0.9:4b_32g s4, 4.23 bpw
#  -- Module quantized, rfn_error: 0.008168
#  -- Layer: model.layers.22 (MLP)
#  -- Linear: model.layers.22.mlp.gate_proj -> 0.1:5b_32g/0.9:4b_32g s4, 4.23 bpw
#  -- Linear: model.layers.22.mlp.up_proj -> 0.25:5b_32g/0.75:4b_32g s4, 4.38 bpw
#  -- Linear: model.layers.22.mlp.down_proj -> 0.05:8b_32g/0.1:5b_32g/0.85:4b_32g s4, 4.44 bpw
#  -- Module quantized, rfn_error: 0.014587
#  -- Layer: model.layers.23 (Attention)
#  -- Linear: model.layers.23.self_attn.q_proj -> 0.1:5b_32g/0.9:4b_32g s4, 4.23 bpw
#  -- Linear: model.layers.23.self_attn.k_proj -> 0.1:5b_32g/0.9:4b_32g s4, 4.23 bpw
#  -- Linear: model.layers.23.self_attn.v_proj -> 1:5b_32g s4, 5.13 bpw
#  -- Linear: model.layers.23.self_attn.o_proj -> 0.1:5b_32g/0.9:4b_32g s4, 4.23 bpw
#  -- Module quantized, rfn_error: 0.007382
#  -- Layer: model.layers.23 (MLP)
#  -- Linear: model.layers.23.mlp.gate_proj -> 0.1:5b_32g/0.9:4b_32g s4, 4.23 bpw
#  -- Linear: model.layers.23.mlp.up_proj -> 0.25:5b_32g/0.75:4b_32g s4, 4.38 bpw
#  -- Linear: model.layers.23.mlp.down_proj -> 0.05:8b_32g/0.1:5b_32g/0.85:4b_32g s4, 4.44 bpw
#  -- Module quantized, rfn_error: 0.014998
#  -- Layer: model.layers.24 (Attention)
#  -- Linear: model.layers.24.self_attn.q_proj -> 0.1:5b_32g/0.9:4b_32g s4, 4.23 bpw
#  -- Linear: model.layers.24.self_attn.k_proj -> 0.1:5b_32g/0.9:4b_32g s4, 4.23 bpw
#  -- Linear: model.layers.24.self_attn.v_proj -> 1:5b_32g s4, 5.13 bpw
#  -- Linear: model.layers.24.self_attn.o_proj -> 0.1:5b_32g/0.9:4b_32g s4, 4.23 bpw
#  -- Module quantized, rfn_error: 0.007548
#  -- Layer: model.layers.24 (MLP)
#  -- Linear: model.layers.24.mlp.gate_proj -> 0.1:5b_32g/0.9:4b_32g s4, 4.23 bpw
#  -- Linear: model.layers.24.mlp.up_proj -> 0.25:5b_32g/0.75:4b_32g s4, 4.38 bpw
#  -- Linear: model.layers.24.mlp.down_proj -> 0.05:8b_32g/0.1:5b_32g/0.85:4b_32g s4, 4.44 bpw
#  -- Module quantized, rfn_error: 0.014802
#  -- Layer: model.layers.25 (Attention)
#  -- Linear: model.layers.25.self_attn.q_proj -> 0.1:5b_32g/0.9:4b_32g s4, 4.23 bpw
#  -- Linear: model.layers.25.self_attn.k_proj -> 0.1:5b_32g/0.9:4b_32g s4, 4.23 bpw
#  -- Linear: model.layers.25.self_attn.v_proj -> 1:5b_32g s4, 5.13 bpw
#  -- Linear: model.layers.25.self_attn.o_proj -> 0.1:5b_32g/0.9:4b_32g s4, 4.23 bpw
#  -- Module quantized, rfn_error: 0.007323
#  -- Layer: model.layers.25 (MLP)
#  -- Linear: model.layers.25.mlp.gate_proj -> 0.1:5b_32g/0.9:4b_32g s4, 4.23 bpw
#  -- Linear: model.layers.25.mlp.up_proj -> 0.25:5b_32g/0.75:4b_32g s4, 4.38 bpw
#  -- Linear: model.layers.25.mlp.down_proj -> 0.05:8b_32g/0.1:5b_32g/0.85:4b_32g s4, 4.44 bpw
#  -- Module quantized, rfn_error: 0.015246
#  -- Layer: model.layers.26 (Attention)
#  -- Linear: model.layers.26.self_attn.q_proj -> 0.1:5b_32g/0.9:4b_32g s4, 4.23 bpw
#  -- Linear: model.layers.26.self_attn.k_proj -> 0.1:5b_32g/0.9:4b_32g s4, 4.23 bpw
#  -- Linear: model.layers.26.self_attn.v_proj -> 1:5b_32g s4, 5.13 bpw
#  -- Linear: model.layers.26.self_attn.o_proj -> 0.1:5b_32g/0.9:4b_32g s4, 4.23 bpw
#  -- Module quantized, rfn_error: 0.008302
#  -- Layer: model.layers.26 (MLP)
#  -- Linear: model.layers.26.mlp.gate_proj -> 0.1:6b_32g/0.9:5b_32g s4, 5.23 bpw
#  -- Linear: model.layers.26.mlp.up_proj -> 0.25:6b_32g/0.75:5b_32g s4, 5.38 bpw
#  -- Linear: model.layers.26.mlp.down_proj -> 0.05:8b_32g/0.1:6b_32g/0.85:5b_32g s4, 5.38 bpw
#  -- Module quantized, rfn_error: 0.007911
#  -- Layer: model.layers.27 (Attention)
#  -- Linear: model.layers.27.self_attn.q_proj -> 0.1:5b_32g/0.9:4b_32g s4, 4.23 bpw
#  -- Linear: model.layers.27.self_attn.k_proj -> 0.1:5b_32g/0.9:4b_32g s4, 4.23 bpw
#  -- Linear: model.layers.27.self_attn.v_proj -> 1:5b_32g s4, 5.13 bpw
#  -- Linear: model.layers.27.self_attn.o_proj -> 0.1:5b_32g/0.9:4b_32g s4, 4.23 bpw
#  -- Module quantized, rfn_error: 0.007648
#  -- Layer: model.layers.27 (MLP)
#  -- Linear: model.layers.27.mlp.gate_proj -> 0.1:6b_32g/0.9:5b_32g s4, 5.23 bpw
#  -- Linear: model.layers.27.mlp.up_proj -> 0.25:6b_32g/0.75:5b_32g s4, 5.38 bpw
#  -- Linear: model.layers.27.mlp.down_proj -> 0.05:8b_32g/0.1:6b_32g/0.85:5b_32g s4, 5.38 bpw
#  -- Module quantized, rfn_error: 0.008210
#  -- Layer: model.layers.28 (Attention)
#  -- Linear: model.layers.28.self_attn.q_proj -> 0.1:5b_32g/0.9:4b_32g s4, 4.23 bpw
#  -- Linear: model.layers.28.self_attn.k_proj -> 0.1:5b_32g/0.9:4b_32g s4, 4.23 bpw
#  -- Linear: model.layers.28.self_attn.v_proj -> 1:5b_32g s4, 5.13 bpw
#  -- Linear: model.layers.28.self_attn.o_proj -> 0.1:5b_32g/0.9:4b_32g s4, 4.23 bpw
#  -- Module quantized, rfn_error: 0.007807
#  -- Layer: model.layers.28 (MLP)
#  -- Linear: model.layers.28.mlp.gate_proj -> 0.1:6b_32g/0.9:5b_32g s4, 5.23 bpw
#  -- Linear: model.layers.28.mlp.up_proj -> 0.25:6b_32g/0.75:5b_32g s4, 5.38 bpw
#  -- Linear: model.layers.28.mlp.down_proj -> 0.05:8b_32g/0.1:6b_32g/0.85:5b_32g s4, 5.38 bpw
#  -- Module quantized, rfn_error: 0.008613
#  -- Layer: model.layers.29 (Attention)
#  -- Linear: model.layers.29.self_attn.q_proj -> 0.1:5b_32g/0.9:4b_32g s4, 4.23 bpw
#  -- Linear: model.layers.29.self_attn.k_proj -> 0.1:5b_32g/0.9:4b_32g s4, 4.23 bpw
#  -- Linear: model.layers.29.self_attn.v_proj -> 1:5b_32g s4, 5.13 bpw
#  -- Linear: model.layers.29.self_attn.o_proj -> 0.1:5b_32g/0.9:4b_32g s4, 4.23 bpw
#  -- Module quantized, rfn_error: 0.007787
#  -- Layer: model.layers.29 (MLP)
#  -- Linear: model.layers.29.mlp.gate_proj -> 0.1:6b_32g/0.9:5b_32g s4, 5.23 bpw
#  -- Linear: model.layers.29.mlp.up_proj -> 0.25:6b_32g/0.75:5b_32g s4, 5.38 bpw
#  -- Linear: model.layers.29.mlp.down_proj -> 0.05:8b_32g/0.1:6b_32g/0.85:5b_32g s4, 5.38 bpw
#  -- Module quantized, rfn_error: 0.009315
#  -- Layer: model.layers.30 (Attention)
#  -- Linear: model.layers.30.self_attn.q_proj -> 0.1:5b_32g/0.9:4b_32g s4, 4.23 bpw
#  -- Linear: model.layers.30.self_attn.k_proj -> 0.1:5b_32g/0.9:4b_32g s4, 4.23 bpw
#  -- Linear: model.layers.30.self_attn.v_proj -> 1:5b_32g s4, 5.13 bpw
#  -- Linear: model.layers.30.self_attn.o_proj -> 0.1:5b_32g/0.9:4b_32g s4, 4.23 bpw
#  -- Module quantized, rfn_error: 0.008130
#  -- Layer: model.layers.30 (MLP)
#  -- Linear: model.layers.30.mlp.gate_proj -> 0.1:6b_128g/0.9:5b_128g s4, 5.16 bpw
#  -- Linear: model.layers.30.mlp.up_proj -> 0.25:6b_128g/0.75:5b_128g s4, 5.28 bpw
#  -- Linear: model.layers.30.mlp.down_proj -> 0.05:8b_32g/0.1:6b_128g/0.85:5b_128g s4, 5.30 bpw
#  -- Module quantized, rfn_error: 0.014766
#  -- Layer: model.layers.31 (Attention)
#  -- Linear: model.layers.31.self_attn.q_proj -> 0.1:5b_32g/0.9:4b_32g s4, 4.23 bpw
#  -- Linear: model.layers.31.self_attn.k_proj -> 0.1:5b_32g/0.9:4b_32g s4, 4.23 bpw
#  -- Linear: model.layers.31.self_attn.v_proj -> 1:5b_32g s4, 5.13 bpw
#  -- Linear: model.layers.31.self_attn.o_proj -> 0.1:5b_32g/0.9:4b_32g s4, 4.23 bpw
#  -- Module quantized, rfn_error: 0.009837
#  -- Layer: model.layers.31 (MLP)
#  -- Linear: model.layers.31.mlp.gate_proj -> 0.1:6b_32g/0.9:5b_32g s4, 5.23 bpw
#  -- Linear: model.layers.31.mlp.up_proj -> 0.25:6b_32g/0.75:5b_32g s4, 5.38 bpw
#  -- Linear: model.layers.31.mlp.down_proj -> 0.05:8b_32g/0.1:6b_32g/0.85:5b_32g s4, 5.38 bpw
#  -- Module quantized, rfn_error: 0.012009
#  -- Layer: model.norm (RMSNorm)
#  -- Module quantized, rfn_error: 0.000000
#  -- Layer: lm_head (Linear)
#  -- Linear: lm_head -> 0.15:8b_128g/0.85:6b_128g s4, 6.34 bpw
#  -- Module quantized, calibration perplexity (quant): 9.6570
#  -- Compiling output file...
#  -- Writing shard 1...
#  --   quant_model/output.safetensors (3,718 MB)
#  -- Finished
# sending incremental file list
# ./
# README.md
# config.json
# generation_config.json
# model.safetensors.index.json
# seal_logo.png
# special_tokens_map.json
# tokenizer.json
# tokenizer.model
# tokenizer_config.json
#
# sent 4,263,995 bytes  received 190 bytes  8,528,370.00 bytes/sec
# total size is 4,262,271  speedup is 1.00

# %%
"""Upload model"""
# !git config --global credential.helper store

from huggingface_hub import login
login(token="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")

from huggingface_hub import HfApi
import locale
locale.getpreferredencoding = lambda: "UTF-8"
api = HfApi()

REPO_ID = f"dieusangly/{MODEL_NAME}-exl2"
REPO_BRANCH = f"{BPW:.1f}bpw"

api.create_repo(
    repo_id=REPO_ID,
    repo_type="model",
)
api.create_branch(
    repo_id=REPO_ID,
    branch=REPO_BRANCH,
    repo_type="model",
)
api.upload_folder(
    repo_id=REPO_ID,
    revision=REPO_BRANCH,
    folder_path="quant_model",
)

# %%
# Run model
# !python exllamav2/test_inference.py -m quant_model/ -p "I am a cat"
# Out:
#  -- Model: quant_model/
#  -- Options: []
#  -- Loading model...
#  -- Loading tokenizer...
#  -- Warmup...
#  -- Generating...
#
# I am a cat
#
# ## CHAPTER 3
#
# ### _The Nymphs_
#
# "Nymph," said the young man, "do you know what a nymph is?"
#
# "Yes," she said. "A nymph is a young woman who is not married."
#
# "And do you know what a nymph means?"
#
# "I think it means that she is young and not married."
#
# "That's right," he said. "But there's more to it than that. A nymph is a young woman who is not married, but
#
#  -- Response generated in 2.58 seconds, 128 tokens, 49.56 tokens/second (includes prompt eval.)

# %%
# !cd exllamav2 && python examples/chat_complete_sentence.py -m ../quant_model -l 1024 -mode llama -maxr 50 -pt -ncf
# Out:
#  -- Model: ../quant_model
#  -- Options: ['length: 1024']
#  -- Loading model...
#  -- Loading tokenizer...
#  -- Prompt format: llama
#  -- System prompt:
#
# You are a helpful, respectful and honest assistant. Always answer as helpfully as possible, while being safe.  Your answers should not include any harmful, unethical, racist, sexist, toxic, dangerous, or illegal content. Please ensure that your responses are socially unbiased and positive in nature.
#
# User: Thủ đô của nước Pháp là gì?
#
# Thủ đô của nước Pháp là Paris.
# Paris là trung tâm chính trị, văn hóa và kinh tế của Pháp. Nó cũng là một trong những thành phố lớn nhất châu Âu với hơn 2 triệu dân.
# Đặc điểm nổi bật của Paris là Tháp Eiffel, đại lộ Champs-Élysées, Nhà thờ Đức Bà Notre-Dame de Paris và Công viên Luxembourg.
#
# (Response: 88 tokens, 46.00 tokens/second)
#
# User: Kể tên một món ăn của nước Lào
#
# Một món ăn đặc trưng của Lào là "Som Tarnok". Som Tarnok là một loại thức ăn được làm từ bột gạo trộn với gia vị và gia cầm. Nó thường được thưởng thức vào bữa sáng hoặc bữa tối.
#
# (Response: 61 tokens, 45.09 tokens/second)
#
# User: Giải thích câu: uống nước nhớ nguồn
#
# Câu "uống nước nhớ nguồn" có nghĩa là khi chúng ta uống nước, để biết nguồn gốc của nó. Nghĩa là, chúng ta nên trân trọng nước vì nó là một tài nguyên quý giá trong cuộc sống hàng ngày. Chúng ta nên nhớ ơn những người đã cung cấp nước cho chúng ta, như sông, suối, ao hồ và những nguồn nước khác.
#
# (Response: 78 tokens, 46.07 tokens/second)
#
# User: Traceback (most recent call last):
#   File "/content/exllamav2/examples/chat_complete_sentence.py", line 327, in <module>
#     up = input(col_user + username + ": " + col_default).strip()
# KeyboardInterrupt
# ^C
